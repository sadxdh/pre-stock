# %% [markdown]
# # 基础图表

# %% [markdown]
# ## 读取数据

# %%
import pandas as pd

data = pd.read_csv('海康威视_clean_MaxMin.csv')
data = data[-200:]
data
# Out:
#             date   open  close   high    low     volume  code    5日均线   10日均线  \
# 2910  2022-08-09  31.73  31.96  32.07  31.55   337623.0  2415  31.258  31.244
# 2911  2022-08-10  31.96  32.09  32.30  31.46   391723.0  2415  31.642  31.255
# 2912  2022-08-11  32.29  32.63  32.90  32.26   504344.0  2415  32.062  31.315
# 2913  2022-08-12  32.64  32.71  32.96  32.16   518736.0  2415  32.244  31.462
# 2914  2022-08-15  32.09  31.10  32.09  30.39  1623248.0  2415  32.098  31.463
# ...          ...    ...    ...    ...    ...        ...   ...     ...     ...
# 3105  2023-05-31  35.17  34.86  35.48  34.60   257120.0  2415  34.882  35.342
# 3106  2023-06-01  34.89  35.90  36.40  34.44   507622.0  2415  35.072  35.449
# 3107  2023-06-02  35.90  35.91  36.08  35.48   296013.0  2415  35.166  35.478
# 3108  2023-06-05  35.92  36.00  36.58  35.61   341780.0  2415  35.566  35.490
# 3109  2023-06-06  36.00  34.90  36.18  34.89   311117.0  2415  35.514  35.312
#
#             涨幅        跌幅        RSI      MACD  MACD_Signal  MACD_Histogram  \
# 2910  0.072123 -0.072123  50.288567 -0.492308    -0.669070        0.176762
# 2911  0.063639 -0.063639  51.325651 -0.400248    -0.615306        0.215058
# 2912  0.068785 -0.068785  55.480391 -0.280482    -0.548341        0.267859
# 2913  0.028616 -0.028616  56.078530 -0.177071    -0.474087        0.297016
# 2914 -0.022934  0.022934  43.431792 -0.222465    -0.423763        0.201297
# ...        ...       ...        ...       ...          ...             ...
# 3105 -0.031667  0.031667  41.617989 -1.021249    -1.175628        0.154379
# 3106  0.027182 -0.027182  47.594390 -0.897751    -1.120053        0.222302
# 3107  0.013262 -0.013262  47.649882 -0.789964    -1.054035        0.264071
# 3108  0.058824 -0.058824  48.181699 -0.689334    -0.981095        0.291761
# 3109 -0.007395  0.007395  42.498959 -0.690387    -0.922953        0.232567
#
#       mixumum  minumum
# 2910    False    False
# 2911    False    False
# 2912    False    False
# 2913     True    False
# 2914    False    False
# ...       ...      ...
# 3105    False    False
# 3106    False    False
# 3107    False    False
# 3108    False    False
# 3109    False    False
#
# [200 rows x 17 columns]

# %% [markdown]
# ## 均线

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'  # 指定中文字体，如宋体或黑体
plt.figure(figsize=(16,8))
data['close'].plot(legend=True)
data['5日均线'].plot(legend=True)
data['10日均线'].plot(legend=True)
plt.savefig("../Visualization/股票数据可视化图表/-200close-均线图.png")

# %% [markdown]
# ## 交易量

# %%
plt.figure(figsize=(16,8))
data['volume'].plot(legend=True)  # 交易量与股价走势 相关性
plt.savefig("../Visualization/股票数据可视化图表/-200交易量.png")

# %% [markdown]
# ## 涨幅

# %%
import numpy as np
plt.figure(figsize=(16,8))
# 添加0基准线
plt.axhline(0, color='red', linestyle='--')
data['涨幅'].plot(legend=True)  # 交易量与股价走势 相关性
plt.rcParams['axes.unicode_minus'] = False
plt.savefig("../Visualization/股票数据可视化图表/-200涨幅.png")

# %% [markdown]
# ## RSI

# %%
# import talib 
# 假设您已经有了一个名为df的DataFrame对象，其中包含日期（在df.index中）和收盘价（在df['close']中）
# 计算RSI指标  相对强弱指标  
# RSI指标基本原理： 
# 通过测量一段时间间内股价上涨总幅度占股价变化总幅度平均值的百分比来评估多空力量的强弱程度， 其能够反映出市场在一定时期内的景气程度
plt.figure(figsize=(16,8))
data['RSI'].plot(legend=True)
plt.savefig("../Visualization/股票数据可视化图表/-200RSI.png")

# %% [markdown]
# ## MACD、macdsignal、macdhist
# MACD线、信号线（signal line,MACD线的9日指数移动均线）、离差图（divergence histogram）
# macd（对应diff）
# macdsignal（对应dea）
# macdhist（对应macd）

# %%
# MACD指标
df = data
# 创建图形对象和子图对象
fig, ax = plt.subplots(figsize=(16, 6))

# 绘制MACD线
ax.plot(df.index, data['MACD'], label='macd（对应diff）')
# 绘制信号线
ax.plot(df.index, data['MACD_Signal'], label='macdsignal（对应dea）')
# 绘制柱状图
ax.bar(df.index, data['MACD_Histogram'], label='macdhist（对应macd）', color='gray')

# 设置图表标题和轴标签
ax.set_title('MACD', fontsize=14)
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('MACD', fontsize=12)

# 设置图例
ax.legend()

# 自动调整日期显示格式
fig.autofmt_xdate()

# 显示图表
plt.show()
# 然后按照下面的原则判断买入还是卖出。       
# 1.DIFF、DEA均为正，DIFF向上突破DEA，买入信号。       
# 2.DIFF、DEA均为负，DIFF向下跌破DEA，卖出信号。       
# 3.DEA线与K线发生背离，行情反转信号。       
# 4.分析MACD柱状线，由正变负，卖出信号；由负变正，买入信号。

# %% [markdown]
# # 特征预测

# %% [markdown]
# ## close预测

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1000:]  # 假设数据存储在名为google_stock_data.csv的文件中

# 提取收盘价列
close_prices = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(close_prices.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# 定义滑动窗口大小
window_size = 5

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_data)):
    X_train.append(train_data[i - window_size:i, 0])
    y_train.append(train_data[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_data[len(scaled_data) - len(test_data) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i, 0])
X_test = np.array(X_test)
# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)
# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_data)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('海康威视 - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)
# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)
print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 5s 6ms/step - loss: 0.0668
# Epoch 2/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0069
# Epoch 3/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0021
# Epoch 4/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 5/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 6/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 7/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 8/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 9/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 10/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 11/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 12/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 13/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 14/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 15/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 16/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 17/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 18/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 19/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 20/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 21/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 22/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 23/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 24/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 25/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 26/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 27/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 28/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 29/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 30/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 31/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 32/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 33/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 34/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 35/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 36/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 37/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 38/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 39/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 40/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 41/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 42/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 43/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 44/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 45/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 46/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 47/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 48/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0013
# Epoch 49/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 50/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0013
# 7/7 [==============================] - 1s 5ms/step
# C:\Users\Administrator\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Administrator\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Administrator\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23041 (\N{CJK UNIFIED IDEOGRAPH-5A01}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Administrator\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 35270 (\N{CJK UNIFIED IDEOGRAPH-89C6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 均方误差 (MSE):  1.4736009347368304
# 均方根误差 (RMSE):  1.2139196574472424

# %% [markdown]
# ## MACD预测

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-2000:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['MACD']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 5

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 5s 7ms/step - loss: 0.0757
# Epoch 2/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0564
# Epoch 3/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0563
# Epoch 4/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0562
# Epoch 5/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0561
# Epoch 6/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0558
# Epoch 7/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0558
# Epoch 8/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0554
# Epoch 9/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0557
# Epoch 10/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0543
# Epoch 11/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0525
# Epoch 12/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0512
# Epoch 13/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0500
# Epoch 14/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0502
# Epoch 15/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0517
# Epoch 16/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0499
# Epoch 17/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0496
# Epoch 18/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0495
# Epoch 19/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0506
# Epoch 20/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0498
# Epoch 21/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 22/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0491
# Epoch 23/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0494
# Epoch 24/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 25/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0495
# Epoch 26/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0499
# Epoch 27/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0499
# Epoch 28/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0494
# Epoch 29/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0493
# Epoch 30/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0492
# Epoch 31/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0491
# Epoch 32/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0493
# Epoch 33/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0493
# Epoch 34/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0490
# Epoch 35/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0499
# Epoch 36/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0493
# Epoch 37/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0489
# Epoch 38/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0495
# Epoch 39/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0490
# Epoch 40/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0492
# Epoch 41/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0495
# Epoch 42/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0488
# Epoch 43/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 44/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0490
# Epoch 45/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0492
# Epoch 46/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0490
# Epoch 47/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0493
# Epoch 48/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0500
# Epoch 49/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0490
# Epoch 50/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0490
# 13/13 [==============================] - 1s 3ms/step
# 均方误差 (MSE):  170.05053183183213
# 均方根误差 (RMSE):  13.040342473717173

# %% [markdown]
# ## MACD_Signal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1500:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['MACD_Signal']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()


# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 4s 9ms/step - loss: 0.0793
# Epoch 2/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0540
# Epoch 3/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0530
# Epoch 4/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0529
# Epoch 5/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0527
# Epoch 6/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0529
# Epoch 7/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0529
# Epoch 8/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0525
# Epoch 9/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0528
# Epoch 10/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0523
# Epoch 11/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0520
# Epoch 12/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0538
# Epoch 13/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0512
# Epoch 14/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0508
# Epoch 15/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0503
# Epoch 16/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0501
# Epoch 17/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0506
# Epoch 18/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0498
# Epoch 19/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0498
# Epoch 20/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0504
# Epoch 21/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0498
# Epoch 22/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0503
# Epoch 23/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0498
# Epoch 24/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0496
# Epoch 25/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0495
# Epoch 26/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0496
# Epoch 27/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0492
# Epoch 28/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0505
# Epoch 29/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0496
# Epoch 30/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0496
# Epoch 31/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0495
# Epoch 32/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0494
# Epoch 33/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0492
# Epoch 34/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0501
# Epoch 35/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0493
# Epoch 36/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0496
# Epoch 37/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0491
# Epoch 38/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0493
# Epoch 39/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0492
# Epoch 40/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0494
# Epoch 41/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0494
# Epoch 42/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0492
# Epoch 43/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0489
# Epoch 44/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0495
# Epoch 45/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0493
# Epoch 46/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0492
# Epoch 47/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0490
# Epoch 48/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0488
# Epoch 49/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0492
# Epoch 50/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0492
# 10/10 [==============================] - 1s 4ms/step
# 均方误差 (MSE):  21.6339851221232
# 均方根误差 (RMSE):  4.651234795419728

# %% [markdown]
# ## *MACD_Histogram

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1500:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['MACD_Histogram']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()


# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 4s 9ms/step - loss: 0.0690
# Epoch 2/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0569
# Epoch 3/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0554
# Epoch 4/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0550
# Epoch 5/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0563
# Epoch 6/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0545
# Epoch 7/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0554
# Epoch 8/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0550
# Epoch 9/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0543
# Epoch 10/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0544
# Epoch 11/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0551
# Epoch 12/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0543
# Epoch 13/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0538
# Epoch 14/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0540
# Epoch 15/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0544
# Epoch 16/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0539
# Epoch 17/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0533
# Epoch 18/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0524
# Epoch 19/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0507
# Epoch 20/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0498
# Epoch 21/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0479
# Epoch 22/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0473
# Epoch 23/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0497
# Epoch 24/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0466
# Epoch 25/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0476
# Epoch 26/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0478
# Epoch 27/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0469
# Epoch 28/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0481
# Epoch 29/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0485
# Epoch 30/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0472
# Epoch 31/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0472
# Epoch 32/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0470
# Epoch 33/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0477
# Epoch 34/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0478
# Epoch 35/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0467
# Epoch 36/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0469
# Epoch 37/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0475
# Epoch 38/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0464
# Epoch 39/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0468
# Epoch 40/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0465
# Epoch 41/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0469
# Epoch 42/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0470
# Epoch 43/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0471
# Epoch 44/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0470
# Epoch 45/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0467
# Epoch 46/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0469
# Epoch 47/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0465
# Epoch 48/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0463
# Epoch 49/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0465
# Epoch 50/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0469
# 10/10 [==============================] - 1s 5ms/step
# 均方误差 (MSE):  25.83522439448434
# 均方根误差 (RMSE):  5.0828362549352635

# %% [markdown]
# ## *MACD,MACD_Signal,MACD_Histogram

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1500:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['MACD','MACD_Signal','MACD_Histogram']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()


# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 4s 9ms/step - loss: 0.0702
# Epoch 2/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0540
# Epoch 3/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0538
# Epoch 4/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0532
# Epoch 5/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0532
# Epoch 6/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0529
# Epoch 7/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0519
# Epoch 8/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0512
# Epoch 9/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0498
# Epoch 10/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0504
# Epoch 11/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0494
# Epoch 12/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0495
# Epoch 13/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0498
# Epoch 14/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0488
# Epoch 15/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0496
# Epoch 16/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0493
# Epoch 17/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0480
# Epoch 18/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0493
# Epoch 19/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0464
# Epoch 20/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0452
# Epoch 21/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0447
# Epoch 22/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0453
# Epoch 23/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0445
# Epoch 24/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0445
# Epoch 25/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0447
# Epoch 26/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0446
# Epoch 27/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0441
# Epoch 28/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0444
# Epoch 29/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0443
# Epoch 30/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0448
# Epoch 31/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0447
# Epoch 32/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0446
# Epoch 33/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0447
# Epoch 34/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0446
# Epoch 35/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0441
# Epoch 36/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0441
# Epoch 37/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0451
# Epoch 38/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0446
# Epoch 39/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0441
# Epoch 40/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0442
# Epoch 41/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0445
# Epoch 42/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0434
# Epoch 43/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0438
# Epoch 44/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0436
# Epoch 45/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0445
# Epoch 46/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0446
# Epoch 47/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0438
# Epoch 48/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0447
# Epoch 49/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0442
# Epoch 50/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0440
# 10/10 [==============================] - 1s 4ms/step
# 均方误差 (MSE):  22.87516542412994
# 均方根误差 (RMSE):  4.782798911111562

# %% [markdown]
# ## RSI预测

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1500:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['RSI']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 4s 9ms/step - loss: 0.0748
# Epoch 2/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0576
# Epoch 3/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0550
# Epoch 4/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0545
# Epoch 5/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0546
# Epoch 6/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0547
# Epoch 7/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0548
# Epoch 8/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 9/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0546
# Epoch 10/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0537
# Epoch 11/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0548
# Epoch 12/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0544
# Epoch 13/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0545
# Epoch 14/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0547
# Epoch 15/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 16/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0539
# Epoch 17/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0543
# Epoch 18/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0539
# Epoch 19/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0548
# Epoch 20/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 21/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 22/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 23/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0540
# Epoch 24/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0546
# Epoch 25/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0537
# Epoch 26/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0543
# Epoch 27/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0542
# Epoch 28/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0537
# Epoch 29/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0537
# Epoch 30/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 31/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 32/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0545
# Epoch 33/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0537
# Epoch 34/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0536
# Epoch 35/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0538
# Epoch 36/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0543
# Epoch 37/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 38/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0538
# Epoch 39/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0536
# Epoch 40/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0533
# Epoch 41/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0541
# Epoch 42/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0532
# Epoch 43/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0533
# Epoch 44/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0535
# Epoch 45/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0531
# Epoch 46/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0530
# Epoch 47/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0536
# Epoch 48/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0529
# Epoch 49/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0528
# Epoch 50/50
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0533
# 10/10 [==============================] - 1s 4ms/step
# 均方误差 (MSE):  26.600536274715452
# 均方根误差 (RMSE):  5.157570772632737

# %% [markdown]
# ## **volume

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-2000:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['volume']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 4s 9ms/step - loss: 0.0699
# Epoch 2/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0538
# Epoch 3/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0527
# Epoch 4/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0530
# Epoch 5/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0529
# Epoch 6/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0516
# Epoch 7/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0499
# Epoch 8/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0444
# Epoch 9/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0444
# Epoch 10/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0437
# Epoch 11/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0438
# Epoch 12/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0443
# Epoch 13/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0436
# Epoch 14/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0436
# Epoch 15/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0437
# Epoch 16/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0439
# Epoch 17/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0431
# Epoch 18/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0429
# Epoch 19/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0435
# Epoch 20/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0423
# Epoch 21/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0440
# Epoch 22/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0427
# Epoch 23/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0429
# Epoch 24/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0428
# Epoch 25/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0426
# Epoch 26/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0427
# Epoch 27/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0421
# Epoch 28/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0419
# Epoch 29/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0424
# Epoch 30/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0418
# Epoch 31/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0424
# Epoch 32/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0422
# Epoch 33/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0422
# Epoch 34/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0423
# Epoch 35/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0419
# Epoch 36/50
# 50/50 [==============================] - 0s 10ms/step - loss: 0.0416
# Epoch 37/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0418
# Epoch 38/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0416
# Epoch 39/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0418
# Epoch 40/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0418
# Epoch 41/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0418
# Epoch 42/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0418
# Epoch 43/50
# 50/50 [==============================] - 0s 10ms/step - loss: 0.0414
# Epoch 44/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0415
# Epoch 45/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0414
# Epoch 46/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0415
# Epoch 47/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0415
# Epoch 48/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0410
# Epoch 49/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0422
# Epoch 50/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0415
# 13/13 [==============================] - 1s 4ms/step
# 均方误差 (MSE):  116.54303664347222
# 均方根误差 (RMSE):  10.795510022387651

# %% [markdown]
# ## high,low,volume,RSI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1000:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['high','low','volume','RSI']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 4s 10ms/step - loss: 0.0350
# Epoch 2/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 3/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 4/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 5/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 6/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 7/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 8/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 9/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 10/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 11/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 12/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 13/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 14/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 15/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 16/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 17/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 18/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 19/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 20/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 21/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 22/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 23/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 24/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 25/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 26/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 27/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 28/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 29/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 30/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 31/50
# 25/25 [==============================] - 0s 9ms/step - loss: 9.7496e-04
# Epoch 32/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 33/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 34/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 35/50
# 25/25 [==============================] - 0s 9ms/step - loss: 9.4362e-04
# Epoch 36/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 37/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 38/50
# 25/25 [==============================] - 0s 9ms/step - loss: 9.6171e-04
# Epoch 39/50
# 25/25 [==============================] - 0s 9ms/step - loss: 9.5596e-04
# Epoch 40/50
# 25/25 [==============================] - 0s 9ms/step - loss: 9.0294e-04
# Epoch 41/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 42/50
# 25/25 [==============================] - 0s 9ms/step - loss: 8.6477e-04
# Epoch 43/50
# 25/25 [==============================] - 0s 9ms/step - loss: 9.0741e-04
# Epoch 44/50
# 25/25 [==============================] - 0s 9ms/step - loss: 9.3666e-04
# Epoch 45/50
# 25/25 [==============================] - 0s 9ms/step - loss: 8.1076e-04
# Epoch 46/50
# 25/25 [==============================] - 0s 9ms/step - loss: 8.6048e-04
# Epoch 47/50
# 25/25 [==============================] - 0s 9ms/step - loss: 8.5616e-04
# Epoch 48/50
# 25/25 [==============================] - 0s 9ms/step - loss: 8.2575e-04
# Epoch 49/50
# 25/25 [==============================] - 0s 9ms/step - loss: 8.2952e-04
# Epoch 50/50
# 25/25 [==============================] - 0s 9ms/step - loss: 8.6802e-04
# 7/7 [==============================] - 1s 4ms/step
# 均方误差 (MSE):  1.140643410025796
# 均方根误差 (RMSE):  1.06800908705207

# %% [markdown]
# ## 涨幅 预测

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1000:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['涨幅']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 4s 11ms/step - loss: 0.0902
# Epoch 2/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0690
# Epoch 3/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0680
# Epoch 4/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0685
# Epoch 5/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0676
# Epoch 6/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0677
# Epoch 7/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0678
# Epoch 8/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0676
# Epoch 9/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0678
# Epoch 10/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0675
# Epoch 11/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0676
# Epoch 12/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 13/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0679
# Epoch 14/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0676
# Epoch 15/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0676
# Epoch 16/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0689
# Epoch 17/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0682
# Epoch 18/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0680
# Epoch 19/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0678
# Epoch 20/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0681
# Epoch 21/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 22/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0673
# Epoch 23/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0677
# Epoch 24/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 25/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 26/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0688
# Epoch 27/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0681
# Epoch 28/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 29/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0675
# Epoch 30/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0673
# Epoch 31/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0684
# Epoch 32/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 33/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0682
# Epoch 34/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0676
# Epoch 35/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0677
# Epoch 36/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0677
# Epoch 37/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0677
# Epoch 38/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0683
# Epoch 39/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0676
# Epoch 40/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0679
# Epoch 41/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0673
# Epoch 42/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0673
# Epoch 43/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 44/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0674
# Epoch 45/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0682
# Epoch 46/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0679
# Epoch 47/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0679
# Epoch 48/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0680
# Epoch 49/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0672
# Epoch 50/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0682
# 7/7 [==============================] - 1s 4ms/step
# 均方误差 (MSE):  45.267459721372354
# 均方根误差 (RMSE):  6.728109669243833

# %% [markdown]
# ## *volume,RSI 预测

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-1000:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['volume','RSI']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 4s 11ms/step - loss: 0.0922
# Epoch 2/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0648
# Epoch 3/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0586
# Epoch 4/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0551
# Epoch 5/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0565
# Epoch 6/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0541
# Epoch 7/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0544
# Epoch 8/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0525
# Epoch 9/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0530
# Epoch 10/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0526
# Epoch 11/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0519
# Epoch 12/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0527
# Epoch 13/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0510
# Epoch 14/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0507
# Epoch 15/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0502
# Epoch 16/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0503
# Epoch 17/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0505
# Epoch 18/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0493
# Epoch 19/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0494
# Epoch 20/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0485
# Epoch 21/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0489
# Epoch 22/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0506
# Epoch 23/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0495
# Epoch 24/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0487
# Epoch 25/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0491
# Epoch 26/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0480
# Epoch 27/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0488
# Epoch 28/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0478
# Epoch 29/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0485
# Epoch 30/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0482
# Epoch 31/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0498
# Epoch 32/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0479
# Epoch 33/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0486
# Epoch 34/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0483
# Epoch 35/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0483
# Epoch 36/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0483
# Epoch 37/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0478
# Epoch 38/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0495
# Epoch 39/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0478
# Epoch 40/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0479
# Epoch 41/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0480
# Epoch 42/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0480
# Epoch 43/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0471
# Epoch 44/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0477
# Epoch 45/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0473
# Epoch 46/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0480
# Epoch 47/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0475
# Epoch 48/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0476
# Epoch 49/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0485
# Epoch 50/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0480
# 7/7 [==============================] - 1s 4ms/step
# 均方误差 (MSE):  57.54426979458571
# 均方根误差 (RMSE):  7.585793946225122

# %% [markdown]
# ## volume，MACD_Histogram

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# 读取数据
data = pd.read_csv('海康威视_clean_MaxMin.csv')[-2000:]  # 假设数据存储在名为stock_data.csv的文件中

# 选择需要使用的特征列
selected_features = ['volume','MACD_Histogram']  # 假设这是您要使用的特征列名称

# 提取特征列数据
features = data[selected_features].values

# 提取目标变量（收盘价）
target = data['close'].values

# 归一化数据
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.reshape(-1, 1))

# 创建训练集和测试集
train_size = int(len(scaled_features) * 0.8)
train_features = scaled_features[:train_size]
train_target = scaled_target[:train_size]
test_features = scaled_features[train_size:]
test_target = scaled_target[train_size:]

# 定义滑动窗口大小
window_size = 10

# 创建输入序列和输出序列
X_train, y_train = [], []
for i in range(window_size, len(train_features)):
    X_train.append(train_features[i - window_size:i])
    y_train.append(train_target[i])
X_train, y_train = np.array(X_train), np.array(y_train)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))

# 构建LSTM模型
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.add(Activation('relu'))
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32)

# 创建测试集的输入序列
inputs = scaled_features[len(scaled_features) - len(test_features) - window_size:]
X_test = []
for i in range(window_size, len(inputs)):
    X_test.append(inputs[i - window_size:i])
X_test = np.array(X_test)

# 转换为LSTM可接受的输入格式 [样本数，时间步数，特征数]
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# 使用模型进行预测
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# 反归一化预测结果
actual_prices = scaler.inverse_transform(test_target)

# 绘制实际收盘价和预测收盘价的走势
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual')
plt.plot(predicted_prices, label='Predicted')
plt.title('Stock Price - Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# 计算均方误差（MSE）
mse = mean_squared_error(actual_prices, predicted_prices)

# 计算均方根误差（RMSE）
rmse = np.sqrt(mse)

print("均方误差 (MSE): ", mse)
print("均方根误差 (RMSE): ", rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 51>()
#      49 model.add(LSTM(units=50))
#      50 model.add(Dense(units=1))
# ---> 51 model.add(Activation('relu'))
#      52 model.compile(optimizer='adam', loss='mean_squared_error')
#      54 # 训练模型
#
# NameError: name 'Activation' is not defined
